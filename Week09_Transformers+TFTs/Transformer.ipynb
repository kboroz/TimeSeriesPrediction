# %%
import torch
import torch.nn as nn
import numpy as np
import time
import math
from matplotlib import pyplot

import os

# Create the 'graph' directory if it doesn't exist
if not os.path.exists('graph'):
    os.makedirs('graph')

torch.manual_seed(0)
np.random.seed(0)

# This concept is also called teacher forceing.
# The flag decides if the loss will be calculted over all
# or just the predicted values.
calculate_loss_over_all_values = False

# S is the source sequence length
# T is the target sequence length
# N is the batch size
# E is the feature number

#src = torch.rand((10, 32, 512)) # (S,N,E)
#tgt = torch.rand((20, 32, 512)) # (T,N,E)
#out = transformer_model(src, tgt)
#
#print(out)

input_window = 100
output_window = 5
batch_size = 10 # batch size
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        #pe.requires_grad = False
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]


class TransAm(nn.Module):
    def __init__(self,feature_size=250,num_layers=1,dropout=0.1):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'

        self.src_mask = None
        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.pos_encoder(src)
        output = self.transformer_encoder(src,self.src_mask)#, self.src_mask)
        output = self.decoder(output)
        return output

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask



# if window is 100 and prediction step is 1
# in -> [0..99]
# target -> [1..100]
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = np.append(input_data[i:i+tw][:-output_window] , output_window * [0])
        train_label = input_data[i:i+tw]
        #train_label = input_data[i+output_window:i+tw+output_window]
        inout_seq.append((train_seq ,train_label))
    return torch.FloatTensor(inout_seq)

def get_data():
    time        = np.arange(0, 400, 0.1)
    amplitude   = np.sin(time) + np.sin(time*0.05) +np.sin(time*0.12) *np.random.normal(-0.2, 0.2, len(time))

    #from pandas import read_csv
    #series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)

    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    #amplitude = scaler.fit_transform(series.to_numpy().reshape(-1, 1)).reshape(-1)
    amplitude = scaler.fit_transform(amplitude.reshape(-1, 1)).reshape(-1)


    sampels = 2800
    train_data = amplitude[:sampels]
    test_data = amplitude[sampels:]

    # convert our train data into a pytorch train tensor
    #train_tensor = torch.FloatTensor(train_data).view(-1)
    # todo: add comment..
    train_sequence = create_inout_sequences(train_data,input_window)
    train_sequence = train_sequence[:-output_window] #todo: fix hack?

    #test_data = torch.FloatTensor(test_data).view(-1)
    test_data = create_inout_sequences(test_data,input_window)
    test_data = test_data[:-output_window] #todo: fix hack?

    return train_sequence.to(device),test_data.to(device)

def get_batch(source, i,batch_size):
    seq_len = min(batch_size, len(source) - 1 - i)
    data = source[i:i+seq_len]
    input = torch.stack(torch.stack([item[0] for item in data]).chunk(input_window,1)) # 1 is feature size
    target = torch.stack(torch.stack([item[1] for item in data]).chunk(input_window,1))
    return input, target


def train(train_data):
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()

    for batch, i in enumerate(range(0, len(train_data) - 1, batch_size)):
        data, targets = get_batch(train_data, i,batch_size)
        optimizer.zero_grad()
        output = model(data)

        if calculate_loss_over_all_values:
            loss = criterion(output, targets)
        else:
            loss = criterion(output[-output_window:], targets[-output_window:])

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_data) / batch_size / 5)
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.6f} | {:5.2f} ms | '
                  'loss {:5.5f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // batch_size, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def plot_and_loss(eval_model, data_source,epoch):
    eval_model.eval()
    total_loss = 0.
    test_result = torch.Tensor(0)
    truth = torch.Tensor(0)
    with torch.no_grad():
        for i in range(0, len(data_source) - 1):
            data, target = get_batch(data_source, i,1)
            # look like the model returns static values for the output window
            output = eval_model(data)
            if calculate_loss_over_all_values:
                total_loss += criterion(output, target).item()
            else:
                total_loss += criterion(output[-output_window:], target[-output_window:]).item()

            test_result = torch.cat((test_result, output[-1].view(-1).cpu()), 0) #todo: check this. -> looks good to me
            truth = torch.cat((truth, target[-1].view(-1).cpu()), 0)

    #test_result = test_result.cpu().numpy()
    len(test_result)

    pyplot.plot(test_result,color="red")
    pyplot.plot(truth[:500],color="blue")
    pyplot.plot(test_result-truth,color="green")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.savefig('graph/transformer-epoch%d.png'%epoch)
    pyplot.close()

    return total_loss / i


def predict_future(eval_model, data_source,steps):
    eval_model.eval()
    total_loss = 0.
    test_result = torch.Tensor(0)
    truth = torch.Tensor(0)
    _ , data = get_batch(data_source, 0,1)
    with torch.no_grad():
        for i in range(0, steps,1):
            input = torch.clone(data[-input_window:])
            input[-output_window:] = 0
            output = eval_model(data[-input_window:])
            data = torch.cat((data, output[-1:]))

    data = data.cpu().view(-1)


    pyplot.plot(data,color="red")
    pyplot.plot(data[:input_window],color="blue")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.savefig('graph/transformer-future%d.png'%steps)
    pyplot.close()

# entweder ist hier ein fehler im loss oder in der train methode, aber die ergebnisse sind unterschiedlich
# auch zu denen der predict_future
def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    eval_batch_size = 1000
    with torch.no_grad():
        for i in range(0, len(data_source) - 1, eval_batch_size):
            data, targets = get_batch(data_source, i,eval_batch_size)
            output = eval_model(data)
            if calculate_loss_over_all_values:
                total_loss += len(data[0])* criterion(output, targets).cpu().item()
            else:
                total_loss += len(data[0])* criterion(output[-output_window:], targets[-output_window:]).cpu().item()
    return total_loss / len(data_source)

train_data, val_data = get_data()
model = TransAm().to(device)

criterion = nn.MSELoss()
lr = 0.005
#optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.98)

best_val_loss = float("inf")
epochs = 100 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(train_data)


    if(epoch % 10 is 0):
        val_loss = plot_and_loss(model, val_data,epoch)
        predict_future(model, val_data,200)
    else:
        val_loss = evaluate(model, val_data)

    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.5f} | valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    #if val_loss < best_val_loss:
    #    best_val_loss = val_loss
    #    best_model = model

    scheduler.step()

#src = torch.rand(input_window, batch_size, 1) # (source sequence length,batch size,feature number)
#out = model(src)
#
#print(out)
#print(out.shape)
# Out:
# <>:262: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:262: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /tmp/ipython-input-2381057624.py:262: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   if(epoch % 10 is 0):
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:523: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# | epoch   1 |    53/  269 batches | lr 0.005000 | 293.00 ms | loss 5.53488 | ppl   253.38
# | epoch   1 |   106/  269 batches | lr 0.005000 | 301.68 ms | loss 0.15555 | ppl     1.17
# | epoch   1 |   159/  269 batches | lr 0.005000 | 307.99 ms | loss 0.15956 | ppl     1.17
# | epoch   1 |   212/  269 batches | lr 0.005000 | 307.05 ms | loss 0.11380 | ppl     1.12
# | epoch   1 |   265/  269 batches | lr 0.005000 | 303.69 ms | loss 0.15046 | ppl     1.16
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 90.09s | valid loss 0.19855 | valid ppl     1.22
# -----------------------------------------------------------------------------------------
# | epoch   2 |    53/  269 batches | lr 0.004802 | 281.49 ms | loss 0.09978 | ppl     1.10
# | epoch   2 |   106/  269 batches | lr 0.004802 | 269.17 ms | loss 0.05865 | ppl     1.06
# | epoch   2 |   159/  269 batches | lr 0.004802 | 286.19 ms | loss 0.06376 | ppl     1.07
# | epoch   2 |   212/  269 batches | lr 0.004802 | 294.43 ms | loss 0.08279 | ppl     1.09
# | epoch   2 |   265/  269 batches | lr 0.004802 | 259.73 ms | loss 0.04767 | ppl     1.05
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 81.48s | valid loss 0.43680 | valid ppl     1.55
# -----------------------------------------------------------------------------------------
# | epoch   3 |    53/  269 batches | lr 0.004706 | 262.70 ms | loss 0.08631 | ppl     1.09
# | epoch   3 |   106/  269 batches | lr 0.004706 | 266.30 ms | loss 0.04026 | ppl     1.04
# | epoch   3 |   159/  269 batches | lr 0.004706 | 263.79 ms | loss 0.01713 | ppl     1.02
# | epoch   3 |   212/  269 batches | lr 0.004706 | 255.21 ms | loss 0.02268 | ppl     1.02
# | epoch   3 |   265/  269 batches | lr 0.004706 | 256.84 ms | loss 0.01861 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 76.94s | valid loss 0.26110 | valid ppl     1.30
# -----------------------------------------------------------------------------------------
# | epoch   4 |    53/  269 batches | lr 0.004612 | 269.75 ms | loss 0.02597 | ppl     1.03
# | epoch   4 |   106/  269 batches | lr 0.004612 | 268.27 ms | loss 0.01548 | ppl     1.02
# | epoch   4 |   159/  269 batches | lr 0.004612 | 253.65 ms | loss 0.01961 | ppl     1.02
# | epoch   4 |   212/  269 batches | lr 0.004612 | 254.37 ms | loss 0.01954 | ppl     1.02
# | epoch   4 |   265/  269 batches | lr 0.004612 | 252.71 ms | loss 0.01415 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 76.54s | valid loss 0.49781 | valid ppl     1.65
# -----------------------------------------------------------------------------------------
# | epoch   5 |    53/  269 batches | lr 0.004520 | 268.58 ms | loss 0.06499 | ppl     1.07
# | epoch   5 |   106/  269 batches | lr 0.004520 | 310.15 ms | loss 0.01386 | ppl     1.01
# | epoch   5 |   159/  269 batches | lr 0.004520 | 253.05 ms | loss 0.01504 | ppl     1.02
# | epoch   5 |   212/  269 batches | lr 0.004520 | 253.81 ms | loss 0.01497 | ppl     1.02
# | epoch   5 |   265/  269 batches | lr 0.004520 | 253.56 ms | loss 0.02913 | ppl     1.03
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 80.81s | valid loss 0.57977 | valid ppl     1.79
# -----------------------------------------------------------------------------------------
# | epoch   6 |    53/  269 batches | lr 0.004429 | 257.31 ms | loss 0.04367 | ppl     1.04
# | epoch   6 |   106/  269 batches | lr 0.004429 | 252.49 ms | loss 0.01717 | ppl     1.02
# | epoch   6 |   159/  269 batches | lr 0.004429 | 252.07 ms | loss 0.01343 | ppl     1.01
# | epoch   6 |   212/  269 batches | lr 0.004429 | 251.19 ms | loss 0.01380 | ppl     1.01
# | epoch   6 |   265/  269 batches | lr 0.004429 | 250.59 ms | loss 0.01580 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 75.38s | valid loss 0.32714 | valid ppl     1.39
# -----------------------------------------------------------------------------------------
# | epoch   7 |    53/  269 batches | lr 0.004341 | 262.12 ms | loss 0.02824 | ppl     1.03
# | epoch   7 |   106/  269 batches | lr 0.004341 | 252.46 ms | loss 0.01423 | ppl     1.01
# | epoch   7 |   159/  269 batches | lr 0.004341 | 251.57 ms | loss 0.01513 | ppl     1.02
# | epoch   7 |   212/  269 batches | lr 0.004341 | 251.46 ms | loss 0.01408 | ppl     1.01
# | epoch   7 |   265/  269 batches | lr 0.004341 | 250.60 ms | loss 0.01776 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 75.12s | valid loss 0.33717 | valid ppl     1.40
# -----------------------------------------------------------------------------------------
# | epoch   8 |    53/  269 batches | lr 0.004254 | 265.10 ms | loss 0.02980 | ppl     1.03
# | epoch   8 |   106/  269 batches | lr 0.004254 | 257.97 ms | loss 0.01281 | ppl     1.01
# | epoch   8 |   159/  269 batches | lr 0.004254 | 250.64 ms | loss 0.01173 | ppl     1.01
# | epoch   8 |   212/  269 batches | lr 0.004254 | 251.20 ms | loss 0.01487 | ppl     1.01
# | epoch   8 |   265/  269 batches | lr 0.004254 | 251.18 ms | loss 0.01197 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 75.37s | valid loss 0.36005 | valid ppl     1.43
# -----------------------------------------------------------------------------------------
# | epoch   9 |    53/  269 batches | lr 0.004169 | 257.16 ms | loss 0.03132 | ppl     1.03
# | epoch   9 |   106/  269 batches | lr 0.004169 | 258.71 ms | loss 0.01441 | ppl     1.01
# | epoch   9 |   159/  269 batches | lr 0.004169 | 253.77 ms | loss 0.01021 | ppl     1.01
# | epoch   9 |   212/  269 batches | lr 0.004169 | 254.47 ms | loss 0.01306 | ppl     1.01
# | epoch   9 |   265/  269 batches | lr 0.004169 | 249.68 ms | loss 0.01551 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 75.23s | valid loss 0.32285 | valid ppl     1.38
# -----------------------------------------------------------------------------------------
# | epoch  10 |    53/  269 batches | lr 0.004085 | 254.89 ms | loss 0.02992 | ppl     1.03
# | epoch  10 |   106/  269 batches | lr 0.004085 | 250.56 ms | loss 0.01116 | ppl     1.01
# | epoch  10 |   159/  269 batches | lr 0.004085 | 253.90 ms | loss 0.01401 | ppl     1.01
# | epoch  10 |   212/  269 batches | lr 0.004085 | 258.99 ms | loss 0.01276 | ppl     1.01
# | epoch  10 |   265/  269 batches | lr 0.004085 | 256.19 ms | loss 0.01494 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 77.89s | valid loss 0.42557 | valid ppl     1.53
# -----------------------------------------------------------------------------------------
# | epoch  11 |    53/  269 batches | lr 0.004004 | 260.97 ms | loss 0.04175 | ppl     1.04
# | epoch  11 |   106/  269 batches | lr 0.004004 | 256.42 ms | loss 0.01079 | ppl     1.01
# | epoch  11 |   159/  269 batches | lr 0.004004 | 254.48 ms | loss 0.01389 | ppl     1.01
# | epoch  11 |   212/  269 batches | lr 0.004004 | 251.17 ms | loss 0.01219 | ppl     1.01
# | epoch  11 |   265/  269 batches | lr 0.004004 | 249.36 ms | loss 0.01460 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 75.22s | valid loss 0.37218 | valid ppl     1.45
# -----------------------------------------------------------------------------------------
# | epoch  12 |    53/  269 batches | lr 0.003924 | 254.17 ms | loss 0.03665 | ppl     1.04
# | epoch  12 |   106/  269 batches | lr 0.003924 | 250.22 ms | loss 0.00981 | ppl     1.01
# | epoch  12 |   159/  269 batches | lr 0.003924 | 255.20 ms | loss 0.01418 | ppl     1.01
# | epoch  12 |   212/  269 batches | lr 0.003924 | 257.00 ms | loss 0.01125 | ppl     1.01
# | epoch  12 |   265/  269 batches | lr 0.003924 | 257.77 ms | loss 0.01477 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 75.32s | valid loss 0.39257 | valid ppl     1.48
# -----------------------------------------------------------------------------------------
# | epoch  13 |    53/  269 batches | lr 0.003845 | 254.42 ms | loss 0.03684 | ppl     1.04
# | epoch  13 |   106/  269 batches | lr 0.003845 | 309.66 ms | loss 0.01077 | ppl     1.01
# | epoch  13 |   159/  269 batches | lr 0.003845 | 254.57 ms | loss 0.01306 | ppl     1.01
# | epoch  13 |   212/  269 batches | lr 0.003845 | 251.01 ms | loss 0.01248 | ppl     1.01
# | epoch  13 |   265/  269 batches | lr 0.003845 | 249.92 ms | loss 0.01301 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 79.03s | valid loss 0.41949 | valid ppl     1.52
# -----------------------------------------------------------------------------------------
# | epoch  14 |    53/  269 batches | lr 0.003768 | 265.56 ms | loss 0.03608 | ppl     1.04
# | epoch  14 |   106/  269 batches | lr 0.003768 | 260.99 ms | loss 0.00937 | ppl     1.01
# | epoch  14 |   159/  269 batches | lr 0.003768 | 253.34 ms | loss 0.01634 | ppl     1.02
# | epoch  14 |   212/  269 batches | lr 0.003768 | 250.91 ms | loss 0.01247 | ppl     1.01
# | epoch  14 |   265/  269 batches | lr 0.003768 | 252.97 ms | loss 0.01452 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 75.80s | valid loss 0.41417 | valid ppl     1.51
# -----------------------------------------------------------------------------------------
# | epoch  15 |    53/  269 batches | lr 0.003693 | 262.62 ms | loss 0.03494 | ppl     1.04
# | epoch  15 |   106/  269 batches | lr 0.003693 | 260.67 ms | loss 0.00964 | ppl     1.01
# | epoch  15 |   159/  269 batches | lr 0.003693 | 255.13 ms | loss 0.01431 | ppl     1.01
# | epoch  15 |   212/  269 batches | lr 0.003693 | 251.07 ms | loss 0.01594 | ppl     1.02
# | epoch  15 |   265/  269 batches | lr 0.003693 | 249.26 ms | loss 0.01362 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 75.49s | valid loss 0.44250 | valid ppl     1.56
# -----------------------------------------------------------------------------------------
# | epoch  16 |    53/  269 batches | lr 0.003619 | 253.92 ms | loss 0.03766 | ppl     1.04
# | epoch  16 |   106/  269 batches | lr 0.003619 | 253.56 ms | loss 0.00958 | ppl     1.01
# | epoch  16 |   159/  269 batches | lr 0.003619 | 257.87 ms | loss 0.01744 | ppl     1.02
# | epoch  16 |   212/  269 batches | lr 0.003619 | 258.60 ms | loss 0.01349 | ppl     1.01
# | epoch  16 |   265/  269 batches | lr 0.003619 | 254.36 ms | loss 0.01389 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 75.49s | valid loss 0.42807 | valid ppl     1.53
# -----------------------------------------------------------------------------------------
# | epoch  17 |    53/  269 batches | lr 0.003547 | 256.04 ms | loss 0.03161 | ppl     1.03
# | epoch  17 |   106/  269 batches | lr 0.003547 | 250.25 ms | loss 0.01191 | ppl     1.01
# | epoch  17 |   159/  269 batches | lr 0.003547 | 250.84 ms | loss 0.02248 | ppl     1.02
# | epoch  17 |   212/  269 batches | lr 0.003547 | 257.81 ms | loss 0.01554 | ppl     1.02
# | epoch  17 |   265/  269 batches | lr 0.003547 | 257.01 ms | loss 0.01631 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 75.43s | valid loss 0.42299 | valid ppl     1.53
# -----------------------------------------------------------------------------------------
# | epoch  18 |    53/  269 batches | lr 0.003476 | 253.75 ms | loss 0.02768 | ppl     1.03
# | epoch  18 |   106/  269 batches | lr 0.003476 | 250.20 ms | loss 0.01167 | ppl     1.01
# | epoch  18 |   159/  269 batches | lr 0.003476 | 250.87 ms | loss 0.02016 | ppl     1.02
# | epoch  18 |   212/  269 batches | lr 0.003476 | 249.12 ms | loss 0.01176 | ppl     1.01
# | epoch  18 |   265/  269 batches | lr 0.003476 | 253.50 ms | loss 0.01473 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 75.20s | valid loss 0.44766 | valid ppl     1.56
# -----------------------------------------------------------------------------------------
# | epoch  19 |    53/  269 batches | lr 0.003406 | 254.97 ms | loss 0.03200 | ppl     1.03
# | epoch  19 |   106/  269 batches | lr 0.003406 | 251.49 ms | loss 0.01211 | ppl     1.01
# | epoch  19 |   159/  269 batches | lr 0.003406 | 252.60 ms | loss 0.02140 | ppl     1.02
# | epoch  19 |   212/  269 batches | lr 0.003406 | 251.72 ms | loss 0.01438 | ppl     1.01
# | epoch  19 |   265/  269 batches | lr 0.003406 | 250.52 ms | loss 0.01405 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 75.62s | valid loss 0.38430 | valid ppl     1.47
# -----------------------------------------------------------------------------------------
# | epoch  20 |    53/  269 batches | lr 0.003338 | 253.42 ms | loss 0.03173 | ppl     1.03
# | epoch  20 |   106/  269 batches | lr 0.003338 | 251.57 ms | loss 0.01119 | ppl     1.01
# | epoch  20 |   159/  269 batches | lr 0.003338 | 252.62 ms | loss 0.01974 | ppl     1.02
# | epoch  20 |   212/  269 batches | lr 0.003338 | 251.50 ms | loss 0.01391 | ppl     1.01
# | epoch  20 |   265/  269 batches | lr 0.003338 | 252.09 ms | loss 0.01300 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 78.11s | valid loss 0.37181 | valid ppl     1.45
# -----------------------------------------------------------------------------------------
# | epoch  21 |    53/  269 batches | lr 0.003271 | 256.81 ms | loss 0.03021 | ppl     1.03
# | epoch  21 |   106/  269 batches | lr 0.003271 | 307.91 ms | loss 0.01483 | ppl     1.01
# | epoch  21 |   159/  269 batches | lr 0.003271 | 257.89 ms | loss 0.02603 | ppl     1.03
# | epoch  21 |   212/  269 batches | lr 0.003271 | 250.48 ms | loss 0.01399 | ppl     1.01
# | epoch  21 |   265/  269 batches | lr 0.003271 | 251.60 ms | loss 0.01365 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 79.30s | valid loss 0.34388 | valid ppl     1.41
# -----------------------------------------------------------------------------------------
# | epoch  22 |    53/  269 batches | lr 0.003206 | 262.01 ms | loss 0.02737 | ppl     1.03
# | epoch  22 |   106/  269 batches | lr 0.003206 | 257.13 ms | loss 0.01472 | ppl     1.01
# | epoch  22 |   159/  269 batches | lr 0.003206 | 253.46 ms | loss 0.01845 | ppl     1.02
# | epoch  22 |   212/  269 batches | lr 0.003206 | 251.58 ms | loss 0.01007 | ppl     1.01
# | epoch  22 |   265/  269 batches | lr 0.003206 | 250.64 ms | loss 0.01579 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 75.28s | valid loss 0.31880 | valid ppl     1.38
# -----------------------------------------------------------------------------------------
# | epoch  23 |    53/  269 batches | lr 0.003142 | 256.86 ms | loss 0.03296 | ppl     1.03
# | epoch  23 |   106/  269 batches | lr 0.003142 | 256.19 ms | loss 0.01629 | ppl     1.02
# | epoch  23 |   159/  269 batches | lr 0.003142 | 258.46 ms | loss 0.02022 | ppl     1.02
# | epoch  23 |   212/  269 batches | lr 0.003142 | 254.45 ms | loss 0.01387 | ppl     1.01
# | epoch  23 |   265/  269 batches | lr 0.003142 | 251.49 ms | loss 0.01432 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 75.42s | valid loss 0.32947 | valid ppl     1.39
# -----------------------------------------------------------------------------------------
# | epoch  24 |    53/  269 batches | lr 0.003079 | 254.46 ms | loss 0.03808 | ppl     1.04
# | epoch  24 |   106/  269 batches | lr 0.003079 | 250.40 ms | loss 0.01879 | ppl     1.02
# | epoch  24 |   159/  269 batches | lr 0.003079 | 250.90 ms | loss 0.01644 | ppl     1.02
# | epoch  24 |   212/  269 batches | lr 0.003079 | 255.57 ms | loss 0.01083 | ppl     1.01
# | epoch  24 |   265/  269 batches | lr 0.003079 | 255.56 ms | loss 0.01297 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 75.17s | valid loss 0.32938 | valid ppl     1.39
# -----------------------------------------------------------------------------------------
# | epoch  25 |    53/  269 batches | lr 0.003017 | 255.01 ms | loss 0.04300 | ppl     1.04
# | epoch  25 |   106/  269 batches | lr 0.003017 | 248.51 ms | loss 0.01971 | ppl     1.02
# | epoch  25 |   159/  269 batches | lr 0.003017 | 249.23 ms | loss 0.01546 | ppl     1.02
# | epoch  25 |   212/  269 batches | lr 0.003017 | 248.55 ms | loss 0.01169 | ppl     1.01
# | epoch  25 |   265/  269 batches | lr 0.003017 | 250.06 ms | loss 0.01238 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 75.03s | valid loss 0.32405 | valid ppl     1.38
# -----------------------------------------------------------------------------------------
# | epoch  26 |    53/  269 batches | lr 0.002957 | 254.48 ms | loss 0.05119 | ppl     1.05
# | epoch  26 |   106/  269 batches | lr 0.002957 | 251.13 ms | loss 0.02204 | ppl     1.02
# | epoch  26 |   159/  269 batches | lr 0.002957 | 250.16 ms | loss 0.01611 | ppl     1.02
# | epoch  26 |   212/  269 batches | lr 0.002957 | 249.91 ms | loss 0.01029 | ppl     1.01
# | epoch  26 |   265/  269 batches | lr 0.002957 | 249.56 ms | loss 0.01359 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 75.16s | valid loss 0.32413 | valid ppl     1.38
# -----------------------------------------------------------------------------------------
# | epoch  27 |    53/  269 batches | lr 0.002898 | 255.25 ms | loss 0.06218 | ppl     1.06
# | epoch  27 |   106/  269 batches | lr 0.002898 | 249.39 ms | loss 0.02274 | ppl     1.02
# | epoch  27 |   159/  269 batches | lr 0.002898 | 249.94 ms | loss 0.01694 | ppl     1.02
# | epoch  27 |   212/  269 batches | lr 0.002898 | 249.53 ms | loss 0.01063 | ppl     1.01
# | epoch  27 |   265/  269 batches | lr 0.002898 | 250.77 ms | loss 0.01474 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 75.22s | valid loss 0.31325 | valid ppl     1.37
# -----------------------------------------------------------------------------------------
# | epoch  28 |    53/  269 batches | lr 0.002840 | 254.83 ms | loss 0.06248 | ppl     1.06
# | epoch  28 |   106/  269 batches | lr 0.002840 | 250.21 ms | loss 0.02977 | ppl     1.03
# | epoch  28 |   159/  269 batches | lr 0.002840 | 250.51 ms | loss 0.01953 | ppl     1.02
# | epoch  28 |   212/  269 batches | lr 0.002840 | 251.18 ms | loss 0.01103 | ppl     1.01
# | epoch  28 |   265/  269 batches | lr 0.002840 | 250.57 ms | loss 0.01403 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 75.54s | valid loss 0.31134 | valid ppl     1.37
# -----------------------------------------------------------------------------------------
# | epoch  29 |    53/  269 batches | lr 0.002783 | 257.42 ms | loss 0.06297 | ppl     1.06
# | epoch  29 |   106/  269 batches | lr 0.002783 | 280.98 ms | loss 0.03696 | ppl     1.04
# | epoch  29 |   159/  269 batches | lr 0.002783 | 267.72 ms | loss 0.02144 | ppl     1.02
# | epoch  29 |   212/  269 batches | lr 0.002783 | 252.05 ms | loss 0.01099 | ppl     1.01
# | epoch  29 |   265/  269 batches | lr 0.002783 | 253.37 ms | loss 0.01500 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 79.50s | valid loss 0.31111 | valid ppl     1.36
# -----------------------------------------------------------------------------------------
# | epoch  30 |    53/  269 batches | lr 0.002727 | 255.72 ms | loss 0.06211 | ppl     1.06
# | epoch  30 |   106/  269 batches | lr 0.002727 | 251.74 ms | loss 0.04302 | ppl     1.04
# | epoch  30 |   159/  269 batches | lr 0.002727 | 252.47 ms | loss 0.02455 | ppl     1.02
# | epoch  30 |   212/  269 batches | lr 0.002727 | 251.85 ms | loss 0.01283 | ppl     1.01
# | epoch  30 |   265/  269 batches | lr 0.002727 | 251.39 ms | loss 0.01365 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 78.36s | valid loss 0.31297 | valid ppl     1.37
# -----------------------------------------------------------------------------------------
# | epoch  31 |    53/  269 batches | lr 0.002673 | 256.06 ms | loss 0.06193 | ppl     1.06
# | epoch  31 |   106/  269 batches | lr 0.002673 | 251.23 ms | loss 0.04507 | ppl     1.05
# | epoch  31 |   159/  269 batches | lr 0.002673 | 250.92 ms | loss 0.02054 | ppl     1.02
# | epoch  31 |   212/  269 batches | lr 0.002673 | 256.09 ms | loss 0.01374 | ppl     1.01
# | epoch  31 |   265/  269 batches | lr 0.002673 | 260.81 ms | loss 0.01301 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 75.65s | valid loss 0.29090 | valid ppl     1.34
# -----------------------------------------------------------------------------------------
# | epoch  32 |    53/  269 batches | lr 0.002619 | 256.13 ms | loss 0.05811 | ppl     1.06
# | epoch  32 |   106/  269 batches | lr 0.002619 | 252.48 ms | loss 0.05804 | ppl     1.06
# | epoch  32 |   159/  269 batches | lr 0.002619 | 250.95 ms | loss 0.02238 | ppl     1.02
# | epoch  32 |   212/  269 batches | lr 0.002619 | 253.25 ms | loss 0.01353 | ppl     1.01
# | epoch  32 |   265/  269 batches | lr 0.002619 | 257.74 ms | loss 0.01330 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 75.71s | valid loss 0.26953 | valid ppl     1.31
# -----------------------------------------------------------------------------------------
# | epoch  33 |    53/  269 batches | lr 0.002567 | 256.42 ms | loss 0.05586 | ppl     1.06
# | epoch  33 |   106/  269 batches | lr 0.002567 | 251.30 ms | loss 0.07268 | ppl     1.08
# | epoch  33 |   159/  269 batches | lr 0.002567 | 252.42 ms | loss 0.03117 | ppl     1.03
# | epoch  33 |   212/  269 batches | lr 0.002567 | 252.35 ms | loss 0.01891 | ppl     1.02
# | epoch  33 |   265/  269 batches | lr 0.002567 | 253.11 ms | loss 0.01396 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 75.76s | valid loss 0.26460 | valid ppl     1.30
# -----------------------------------------------------------------------------------------
# | epoch  34 |    53/  269 batches | lr 0.002516 | 257.96 ms | loss 0.05218 | ppl     1.05
# | epoch  34 |   106/  269 batches | lr 0.002516 | 252.71 ms | loss 0.07378 | ppl     1.08
# | epoch  34 |   159/  269 batches | lr 0.002516 | 251.97 ms | loss 0.02771 | ppl     1.03
# | epoch  34 |   212/  269 batches | lr 0.002516 | 250.80 ms | loss 0.01421 | ppl     1.01
# | epoch  34 |   265/  269 batches | lr 0.002516 | 251.06 ms | loss 0.01410 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 75.83s | valid loss 0.23111 | valid ppl     1.26
# -----------------------------------------------------------------------------------------
# | epoch  35 |    53/  269 batches | lr 0.002465 | 255.74 ms | loss 0.04625 | ppl     1.05
# | epoch  35 |   106/  269 batches | lr 0.002465 | 251.13 ms | loss 0.09786 | ppl     1.10
# | epoch  35 |   159/  269 batches | lr 0.002465 | 250.55 ms | loss 0.02485 | ppl     1.03
# | epoch  35 |   212/  269 batches | lr 0.002465 | 250.30 ms | loss 0.01610 | ppl     1.02
# | epoch  35 |   265/  269 batches | lr 0.002465 | 251.53 ms | loss 0.01339 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 75.33s | valid loss 0.21001 | valid ppl     1.23
# -----------------------------------------------------------------------------------------
# | epoch  36 |    53/  269 batches | lr 0.002416 | 255.22 ms | loss 0.04139 | ppl     1.04
# | epoch  36 |   106/  269 batches | lr 0.002416 | 251.18 ms | loss 0.05824 | ppl     1.06
# | epoch  36 |   159/  269 batches | lr 0.002416 | 257.13 ms | loss 0.02693 | ppl     1.03
# | epoch  36 |   212/  269 batches | lr 0.002416 | 251.29 ms | loss 0.01820 | ppl     1.02
# | epoch  36 |   265/  269 batches | lr 0.002416 | 250.85 ms | loss 0.01504 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 75.81s | valid loss 0.20350 | valid ppl     1.23
# -----------------------------------------------------------------------------------------
# | epoch  37 |    53/  269 batches | lr 0.002368 | 255.76 ms | loss 0.04199 | ppl     1.04
# | epoch  37 |   106/  269 batches | lr 0.002368 | 300.73 ms | loss 0.06459 | ppl     1.07
# | epoch  37 |   159/  269 batches | lr 0.002368 | 253.32 ms | loss 0.02757 | ppl     1.03
# | epoch  37 |   212/  269 batches | lr 0.002368 | 254.16 ms | loss 0.01630 | ppl     1.02
# | epoch  37 |   265/  269 batches | lr 0.002368 | 252.80 ms | loss 0.01462 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 79.96s | valid loss 0.19332 | valid ppl     1.21
# -----------------------------------------------------------------------------------------
# | epoch  38 |    53/  269 batches | lr 0.002320 | 257.16 ms | loss 0.03828 | ppl     1.04
# | epoch  38 |   106/  269 batches | lr 0.002320 | 251.82 ms | loss 0.06668 | ppl     1.07
# | epoch  38 |   159/  269 batches | lr 0.002320 | 252.88 ms | loss 0.02955 | ppl     1.03
# | epoch  38 |   212/  269 batches | lr 0.002320 | 251.67 ms | loss 0.02514 | ppl     1.03
# | epoch  38 |   265/  269 batches | lr 0.002320 | 251.95 ms | loss 0.01475 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 75.82s | valid loss 0.20168 | valid ppl     1.22
# -----------------------------------------------------------------------------------------
# | epoch  39 |    53/  269 batches | lr 0.002274 | 257.70 ms | loss 0.03563 | ppl     1.04
# | epoch  39 |   106/  269 batches | lr 0.002274 | 253.24 ms | loss 0.06325 | ppl     1.07
# | epoch  39 |   159/  269 batches | lr 0.002274 | 252.05 ms | loss 0.02893 | ppl     1.03
# | epoch  39 |   212/  269 batches | lr 0.002274 | 251.84 ms | loss 0.01715 | ppl     1.02
# | epoch  39 |   265/  269 batches | lr 0.002274 | 251.96 ms | loss 0.01517 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 75.86s | valid loss 0.19751 | valid ppl     1.22
# -----------------------------------------------------------------------------------------
# | epoch  40 |    53/  269 batches | lr 0.002229 | 257.48 ms | loss 0.03361 | ppl     1.03
# | epoch  40 |   106/  269 batches | lr 0.002229 | 251.78 ms | loss 0.06361 | ppl     1.07
# | epoch  40 |   159/  269 batches | lr 0.002229 | 252.42 ms | loss 0.03125 | ppl     1.03
# | epoch  40 |   212/  269 batches | lr 0.002229 | 251.72 ms | loss 0.01764 | ppl     1.02
# | epoch  40 |   265/  269 batches | lr 0.002229 | 251.93 ms | loss 0.01402 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 78.37s | valid loss 0.21529 | valid ppl     1.24
# -----------------------------------------------------------------------------------------
# | epoch  41 |    53/  269 batches | lr 0.002184 | 255.99 ms | loss 0.03237 | ppl     1.03
# | epoch  41 |   106/  269 batches | lr 0.002184 | 251.39 ms | loss 0.05850 | ppl     1.06
# | epoch  41 |   159/  269 batches | lr 0.002184 | 251.54 ms | loss 0.03503 | ppl     1.04
# | epoch  41 |   212/  269 batches | lr 0.002184 | 252.10 ms | loss 0.02398 | ppl     1.02
# | epoch  41 |   265/  269 batches | lr 0.002184 | 258.16 ms | loss 0.01654 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 75.58s | valid loss 0.21159 | valid ppl     1.24
# -----------------------------------------------------------------------------------------
# | epoch  42 |    53/  269 batches | lr 0.002140 | 256.92 ms | loss 0.03233 | ppl     1.03
# | epoch  42 |   106/  269 batches | lr 0.002140 | 251.56 ms | loss 0.05712 | ppl     1.06
# | epoch  42 |   159/  269 batches | lr 0.002140 | 251.66 ms | loss 0.03929 | ppl     1.04
# | epoch  42 |   212/  269 batches | lr 0.002140 | 251.07 ms | loss 0.02812 | ppl     1.03
# | epoch  42 |   265/  269 batches | lr 0.002140 | 252.95 ms | loss 0.01852 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 75.65s | valid loss 0.21025 | valid ppl     1.23
# -----------------------------------------------------------------------------------------
# | epoch  43 |    53/  269 batches | lr 0.002097 | 256.74 ms | loss 0.03326 | ppl     1.03
# | epoch  43 |   106/  269 batches | lr 0.002097 | 251.47 ms | loss 0.05559 | ppl     1.06
# | epoch  43 |   159/  269 batches | lr 0.002097 | 252.43 ms | loss 0.04913 | ppl     1.05
# | epoch  43 |   212/  269 batches | lr 0.002097 | 252.17 ms | loss 0.03786 | ppl     1.04
# | epoch  43 |   265/  269 batches | lr 0.002097 | 250.63 ms | loss 0.02523 | ppl     1.03
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 75.73s | valid loss 0.17741 | valid ppl     1.19
# -----------------------------------------------------------------------------------------
# | epoch  44 |    53/  269 batches | lr 0.002055 | 256.99 ms | loss 0.03109 | ppl     1.03
# | epoch  44 |   106/  269 batches | lr 0.002055 | 252.43 ms | loss 0.05236 | ppl     1.05
# | epoch  44 |   159/  269 batches | lr 0.002055 | 253.23 ms | loss 0.04601 | ppl     1.05
# | epoch  44 |   212/  269 batches | lr 0.002055 | 252.23 ms | loss 0.03269 | ppl     1.03
# | epoch  44 |   265/  269 batches | lr 0.002055 | 252.95 ms | loss 0.02647 | ppl     1.03
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 75.93s | valid loss 0.17140 | valid ppl     1.19
# -----------------------------------------------------------------------------------------
# | epoch  45 |    53/  269 batches | lr 0.002014 | 257.04 ms | loss 0.03174 | ppl     1.03
# | epoch  45 |   106/  269 batches | lr 0.002014 | 308.01 ms | loss 0.04502 | ppl     1.05
# | epoch  45 |   159/  269 batches | lr 0.002014 | 253.41 ms | loss 0.04383 | ppl     1.04
# | epoch  45 |   212/  269 batches | lr 0.002014 | 251.88 ms | loss 0.02687 | ppl     1.03
# | epoch  45 |   265/  269 batches | lr 0.002014 | 252.31 ms | loss 0.02034 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 80.40s | valid loss 0.14427 | valid ppl     1.16
# -----------------------------------------------------------------------------------------
# | epoch  46 |    53/  269 batches | lr 0.001974 | 255.66 ms | loss 0.02607 | ppl     1.03
# | epoch  46 |   106/  269 batches | lr 0.001974 | 251.45 ms | loss 0.04508 | ppl     1.05
# | epoch  46 |   159/  269 batches | lr 0.001974 | 250.50 ms | loss 0.03211 | ppl     1.03
# | epoch  46 |   212/  269 batches | lr 0.001974 | 250.88 ms | loss 0.02585 | ppl     1.03
# | epoch  46 |   265/  269 batches | lr 0.001974 | 251.32 ms | loss 0.01987 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 75.49s | valid loss 0.11999 | valid ppl     1.13
# -----------------------------------------------------------------------------------------
# | epoch  47 |    53/  269 batches | lr 0.001935 | 255.55 ms | loss 0.02340 | ppl     1.02
# | epoch  47 |   106/  269 batches | lr 0.001935 | 250.54 ms | loss 0.03895 | ppl     1.04
# | epoch  47 |   159/  269 batches | lr 0.001935 | 251.21 ms | loss 0.03026 | ppl     1.03
# | epoch  47 |   212/  269 batches | lr 0.001935 | 250.22 ms | loss 0.02417 | ppl     1.02
# | epoch  47 |   265/  269 batches | lr 0.001935 | 250.97 ms | loss 0.01848 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 75.42s | valid loss 0.13719 | valid ppl     1.15
# -----------------------------------------------------------------------------------------
# | epoch  48 |    53/  269 batches | lr 0.001896 | 255.63 ms | loss 0.02322 | ppl     1.02
# | epoch  48 |   106/  269 batches | lr 0.001896 | 249.90 ms | loss 0.03397 | ppl     1.03
# | epoch  48 |   159/  269 batches | lr 0.001896 | 250.79 ms | loss 0.03184 | ppl     1.03
# | epoch  48 |   212/  269 batches | lr 0.001896 | 251.38 ms | loss 0.02179 | ppl     1.02
# | epoch  48 |   265/  269 batches | lr 0.001896 | 249.88 ms | loss 0.01796 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 75.28s | valid loss 0.10222 | valid ppl     1.11
# -----------------------------------------------------------------------------------------
# | epoch  49 |    53/  269 batches | lr 0.001858 | 255.88 ms | loss 0.01906 | ppl     1.02
# | epoch  49 |   106/  269 batches | lr 0.001858 | 249.37 ms | loss 0.03461 | ppl     1.04
# | epoch  49 |   159/  269 batches | lr 0.001858 | 250.72 ms | loss 0.02845 | ppl     1.03
# | epoch  49 |   212/  269 batches | lr 0.001858 | 250.14 ms | loss 0.02230 | ppl     1.02
# | epoch  49 |   265/  269 batches | lr 0.001858 | 249.77 ms | loss 0.01695 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 75.39s | valid loss 0.11537 | valid ppl     1.12
# -----------------------------------------------------------------------------------------
# | epoch  50 |    53/  269 batches | lr 0.001821 | 254.49 ms | loss 0.02149 | ppl     1.02
# | epoch  50 |   106/  269 batches | lr 0.001821 | 250.33 ms | loss 0.02927 | ppl     1.03
# | epoch  50 |   159/  269 batches | lr 0.001821 | 250.88 ms | loss 0.02657 | ppl     1.03
# | epoch  50 |   212/  269 batches | lr 0.001821 | 249.83 ms | loss 0.02111 | ppl     1.02
# | epoch  50 |   265/  269 batches | lr 0.001821 | 250.91 ms | loss 0.01746 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 77.91s | valid loss 0.11499 | valid ppl     1.12
# -----------------------------------------------------------------------------------------
# | epoch  51 |    53/  269 batches | lr 0.001784 | 255.70 ms | loss 0.02224 | ppl     1.02
# | epoch  51 |   106/  269 batches | lr 0.001784 | 249.58 ms | loss 0.02655 | ppl     1.03
# | epoch  51 |   159/  269 batches | lr 0.001784 | 251.03 ms | loss 0.02347 | ppl     1.02
# | epoch  51 |   212/  269 batches | lr 0.001784 | 251.72 ms | loss 0.02052 | ppl     1.02
# | epoch  51 |   265/  269 batches | lr 0.001784 | 251.54 ms | loss 0.01555 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 75.46s | valid loss 0.08019 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  52 |    53/  269 batches | lr 0.001749 | 255.52 ms | loss 0.01734 | ppl     1.02
# | epoch  52 |   106/  269 batches | lr 0.001749 | 251.51 ms | loss 0.02671 | ppl     1.03
# | epoch  52 |   159/  269 batches | lr 0.001749 | 251.64 ms | loss 0.02213 | ppl     1.02
# | epoch  52 |   212/  269 batches | lr 0.001749 | 252.84 ms | loss 0.01985 | ppl     1.02
# | epoch  52 |   265/  269 batches | lr 0.001749 | 253.44 ms | loss 0.01603 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 75.78s | valid loss 0.08264 | valid ppl     1.09
# -----------------------------------------------------------------------------------------
# | epoch  53 |    53/  269 batches | lr 0.001714 | 258.61 ms | loss 0.01799 | ppl     1.02
# | epoch  53 |   106/  269 batches | lr 0.001714 | 313.51 ms | loss 0.02284 | ppl     1.02
# | epoch  53 |   159/  269 batches | lr 0.001714 | 254.23 ms | loss 0.02128 | ppl     1.02
# | epoch  53 |   212/  269 batches | lr 0.001714 | 253.18 ms | loss 0.02001 | ppl     1.02
# | epoch  53 |   265/  269 batches | lr 0.001714 | 253.69 ms | loss 0.01539 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 81.17s | valid loss 0.07884 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  54 |    53/  269 batches | lr 0.001679 | 262.02 ms | loss 0.01677 | ppl     1.02
# | epoch  54 |   106/  269 batches | lr 0.001679 | 253.29 ms | loss 0.02227 | ppl     1.02
# | epoch  54 |   159/  269 batches | lr 0.001679 | 253.53 ms | loss 0.02196 | ppl     1.02
# | epoch  54 |   212/  269 batches | lr 0.001679 | 253.88 ms | loss 0.01898 | ppl     1.02
# | epoch  54 |   265/  269 batches | lr 0.001679 | 258.44 ms | loss 0.01803 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 76.49s | valid loss 0.07034 | valid ppl     1.07
# -----------------------------------------------------------------------------------------
# | epoch  55 |    53/  269 batches | lr 0.001646 | 258.87 ms | loss 0.01576 | ppl     1.02
# | epoch  55 |   106/  269 batches | lr 0.001646 | 253.39 ms | loss 0.01928 | ppl     1.02
# | epoch  55 |   159/  269 batches | lr 0.001646 | 253.85 ms | loss 0.01920 | ppl     1.02
# | epoch  55 |   212/  269 batches | lr 0.001646 | 255.49 ms | loss 0.01971 | ppl     1.02
# | epoch  55 |   265/  269 batches | lr 0.001646 | 260.11 ms | loss 0.01616 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 76.39s | valid loss 0.07422 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  56 |    53/  269 batches | lr 0.001613 | 258.46 ms | loss 0.01786 | ppl     1.02
# | epoch  56 |   106/  269 batches | lr 0.001613 | 253.91 ms | loss 0.02051 | ppl     1.02
# | epoch  56 |   159/  269 batches | lr 0.001613 | 254.06 ms | loss 0.02030 | ppl     1.02
# | epoch  56 |   212/  269 batches | lr 0.001613 | 253.53 ms | loss 0.01950 | ppl     1.02
# | epoch  56 |   265/  269 batches | lr 0.001613 | 255.23 ms | loss 0.01629 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 76.18s | valid loss 0.07246 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  57 |    53/  269 batches | lr 0.001581 | 259.54 ms | loss 0.01890 | ppl     1.02
# | epoch  57 |   106/  269 batches | lr 0.001581 | 253.02 ms | loss 0.01649 | ppl     1.02
# | epoch  57 |   159/  269 batches | lr 0.001581 | 254.07 ms | loss 0.01930 | ppl     1.02
# | epoch  57 |   212/  269 batches | lr 0.001581 | 254.46 ms | loss 0.01821 | ppl     1.02
# | epoch  57 |   265/  269 batches | lr 0.001581 | 256.00 ms | loss 0.01616 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 76.36s | valid loss 0.06788 | valid ppl     1.07
# -----------------------------------------------------------------------------------------
# | epoch  58 |    53/  269 batches | lr 0.001549 | 258.60 ms | loss 0.01922 | ppl     1.02
# | epoch  58 |   106/  269 batches | lr 0.001549 | 252.97 ms | loss 0.01684 | ppl     1.02
# | epoch  58 |   159/  269 batches | lr 0.001549 | 253.34 ms | loss 0.01855 | ppl     1.02
# | epoch  58 |   212/  269 batches | lr 0.001549 | 252.93 ms | loss 0.01809 | ppl     1.02
# | epoch  58 |   265/  269 batches | lr 0.001549 | 254.45 ms | loss 0.01443 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time: 76.14s | valid loss 0.06199 | valid ppl     1.06
# -----------------------------------------------------------------------------------------
# | epoch  59 |    53/  269 batches | lr 0.001518 | 257.69 ms | loss 0.01942 | ppl     1.02
# | epoch  59 |   106/  269 batches | lr 0.001518 | 254.89 ms | loss 0.01858 | ppl     1.02
# | epoch  59 |   159/  269 batches | lr 0.001518 | 254.77 ms | loss 0.01849 | ppl     1.02
# | epoch  59 |   212/  269 batches | lr 0.001518 | 254.27 ms | loss 0.02087 | ppl     1.02
# | epoch  59 |   265/  269 batches | lr 0.001518 | 256.54 ms | loss 0.01533 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time: 76.93s | valid loss 0.07827 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  60 |    53/  269 batches | lr 0.001488 | 257.86 ms | loss 0.02137 | ppl     1.02
# | epoch  60 |   106/  269 batches | lr 0.001488 | 255.56 ms | loss 0.01593 | ppl     1.02
# | epoch  60 |   159/  269 batches | lr 0.001488 | 254.38 ms | loss 0.01949 | ppl     1.02
# | epoch  60 |   212/  269 batches | lr 0.001488 | 255.44 ms | loss 0.02004 | ppl     1.02
# | epoch  60 |   265/  269 batches | lr 0.001488 | 262.91 ms | loss 0.01596 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time: 79.01s | valid loss 0.06647 | valid ppl     1.07
# -----------------------------------------------------------------------------------------
# | epoch  61 |    53/  269 batches | lr 0.001458 | 334.88 ms | loss 0.02149 | ppl     1.02
# | epoch  61 |   106/  269 batches | lr 0.001458 | 266.46 ms | loss 0.01845 | ppl     1.02
# | epoch  61 |   159/  269 batches | lr 0.001458 | 255.78 ms | loss 0.01793 | ppl     1.02
# | epoch  61 |   212/  269 batches | lr 0.001458 | 256.69 ms | loss 0.02171 | ppl     1.02
# | epoch  61 |   265/  269 batches | lr 0.001458 | 256.83 ms | loss 0.01530 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time: 83.14s | valid loss 0.07132 | valid ppl     1.07
# -----------------------------------------------------------------------------------------
# | epoch  62 |    53/  269 batches | lr 0.001429 | 260.14 ms | loss 0.02200 | ppl     1.02
# | epoch  62 |   106/  269 batches | lr 0.001429 | 255.89 ms | loss 0.01802 | ppl     1.02
# | epoch  62 |   159/  269 batches | lr 0.001429 | 255.33 ms | loss 0.01975 | ppl     1.02
# | epoch  62 |   212/  269 batches | lr 0.001429 | 254.98 ms | loss 0.02148 | ppl     1.02
# | epoch  62 |   265/  269 batches | lr 0.001429 | 254.34 ms | loss 0.01515 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time: 76.65s | valid loss 0.08209 | valid ppl     1.09
# -----------------------------------------------------------------------------------------
# | epoch  63 |    53/  269 batches | lr 0.001400 | 258.33 ms | loss 0.02377 | ppl     1.02
# | epoch  63 |   106/  269 batches | lr 0.001400 | 256.55 ms | loss 0.01505 | ppl     1.02
# | epoch  63 |   159/  269 batches | lr 0.001400 | 253.97 ms | loss 0.01908 | ppl     1.02
# | epoch  63 |   212/  269 batches | lr 0.001400 | 253.65 ms | loss 0.01883 | ppl     1.02
# | epoch  63 |   265/  269 batches | lr 0.001400 | 254.14 ms | loss 0.01703 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time: 76.47s | valid loss 0.05549 | valid ppl     1.06
# -----------------------------------------------------------------------------------------
# | epoch  64 |    53/  269 batches | lr 0.001372 | 259.95 ms | loss 0.02100 | ppl     1.02
# | epoch  64 |   106/  269 batches | lr 0.001372 | 253.76 ms | loss 0.01558 | ppl     1.02
# | epoch  64 |   159/  269 batches | lr 0.001372 | 256.06 ms | loss 0.01728 | ppl     1.02
# | epoch  64 |   212/  269 batches | lr 0.001372 | 256.04 ms | loss 0.02180 | ppl     1.02
# | epoch  64 |   265/  269 batches | lr 0.001372 | 257.84 ms | loss 0.01695 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time: 76.96s | valid loss 0.05086 | valid ppl     1.05
# -----------------------------------------------------------------------------------------
# | epoch  65 |    53/  269 batches | lr 0.001345 | 261.87 ms | loss 0.02034 | ppl     1.02
# | epoch  65 |   106/  269 batches | lr 0.001345 | 254.91 ms | loss 0.01496 | ppl     1.02
# | epoch  65 |   159/  269 batches | lr 0.001345 | 254.74 ms | loss 0.01950 | ppl     1.02
# | epoch  65 |   212/  269 batches | lr 0.001345 | 255.58 ms | loss 0.01957 | ppl     1.02
# | epoch  65 |   265/  269 batches | lr 0.001345 | 254.06 ms | loss 0.01610 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time: 76.78s | valid loss 0.04372 | valid ppl     1.04
# -----------------------------------------------------------------------------------------
# | epoch  66 |    53/  269 batches | lr 0.001318 | 258.81 ms | loss 0.01846 | ppl     1.02
# | epoch  66 |   106/  269 batches | lr 0.001318 | 253.45 ms | loss 0.01586 | ppl     1.02
# | epoch  66 |   159/  269 batches | lr 0.001318 | 254.50 ms | loss 0.01794 | ppl     1.02
# | epoch  66 |   212/  269 batches | lr 0.001318 | 254.05 ms | loss 0.02088 | ppl     1.02
# | epoch  66 |   265/  269 batches | lr 0.001318 | 255.21 ms | loss 0.01703 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time: 76.46s | valid loss 0.03672 | valid ppl     1.04
# -----------------------------------------------------------------------------------------
# | epoch  67 |    53/  269 batches | lr 0.001292 | 259.57 ms | loss 0.01808 | ppl     1.02
# | epoch  67 |   106/  269 batches | lr 0.001292 | 255.65 ms | loss 0.01485 | ppl     1.01
# | epoch  67 |   159/  269 batches | lr 0.001292 | 254.38 ms | loss 0.01703 | ppl     1.02
# | epoch  67 |   212/  269 batches | lr 0.001292 | 256.59 ms | loss 0.01959 | ppl     1.02
# | epoch  67 |   265/  269 batches | lr 0.001292 | 255.57 ms | loss 0.01763 | ppl     1.02
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time: 76.61s | valid loss 0.03510 | valid ppl     1.04
# ...
# | epoch  78 |   212/  269 batches | lr 0.001034 | 263.80 ms | loss 0.01437 | ppl     1.01
# | epoch  78 |   265/  269 batches | lr 0.001034 | 260.44 ms | loss 0.01235 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time: 78.36s | valid loss 0.01953 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  79 |    53/  269 batches | lr 0.001014 | 270.18 ms | loss 0.01433 | ppl     1.01
# | epoch  79 |   106/  269 batches | lr 0.001014 | 263.38 ms | loss 0.01079 | ppl     1.01
# | epoch  79 |   159/  269 batches | lr 0.001014 | 258.73 ms | loss 0.01192 | ppl     1.01
# | epoch  79 |   212/  269 batches | lr 0.001014 | 255.50 ms | loss 0.01437 | ppl     1.01
# | epoch  79 |   265/  269 batches | lr 0.001014 | 255.20 ms | loss 0.01217 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time: 77.05s | valid loss 0.01601 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  80 |    53/  269 batches | lr 0.000993 | 270.72 ms | loss 0.01343 | ppl     1.01
# | epoch  80 |   106/  269 batches | lr 0.000993 | 261.17 ms | loss 0.01037 | ppl     1.01
# | epoch  80 |   159/  269 batches | lr 0.000993 | 255.01 ms | loss 0.01229 | ppl     1.01
# | epoch  80 |   212/  269 batches | lr 0.000993 | 256.13 ms | loss 0.01474 | ppl     1.01
# | epoch  80 |   265/  269 batches | lr 0.000993 | 254.63 ms | loss 0.01231 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time: 80.01s | valid loss 0.01599 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  81 |    53/  269 batches | lr 0.000973 | 260.62 ms | loss 0.01354 | ppl     1.01
# | epoch  81 |   106/  269 batches | lr 0.000973 | 254.61 ms | loss 0.01050 | ppl     1.01
# | epoch  81 |   159/  269 batches | lr 0.000973 | 254.46 ms | loss 0.01137 | ppl     1.01
# | epoch  81 |   212/  269 batches | lr 0.000973 | 255.67 ms | loss 0.01443 | ppl     1.01
# | epoch  81 |   265/  269 batches | lr 0.000973 | 255.86 ms | loss 0.01161 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time: 77.00s | valid loss 0.01563 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  82 |    53/  269 batches | lr 0.000954 | 260.98 ms | loss 0.01336 | ppl     1.01
# | epoch  82 |   106/  269 batches | lr 0.000954 | 255.97 ms | loss 0.01057 | ppl     1.01
# | epoch  82 |   159/  269 batches | lr 0.000954 | 254.49 ms | loss 0.01109 | ppl     1.01
# | epoch  82 |   212/  269 batches | lr 0.000954 | 257.29 ms | loss 0.01452 | ppl     1.01
# | epoch  82 |   265/  269 batches | lr 0.000954 | 255.12 ms | loss 0.01147 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time: 76.97s | valid loss 0.01505 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  83 |    53/  269 batches | lr 0.000935 | 259.35 ms | loss 0.01208 | ppl     1.01
# | epoch  83 |   106/  269 batches | lr 0.000935 | 254.42 ms | loss 0.01071 | ppl     1.01
# | epoch  83 |   159/  269 batches | lr 0.000935 | 255.03 ms | loss 0.01111 | ppl     1.01
# | epoch  83 |   212/  269 batches | lr 0.000935 | 259.82 ms | loss 0.01382 | ppl     1.01
# | epoch  83 |   265/  269 batches | lr 0.000935 | 253.50 ms | loss 0.01160 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time: 76.87s | valid loss 0.01539 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  84 |    53/  269 batches | lr 0.000916 | 260.01 ms | loss 0.01156 | ppl     1.01
# | epoch  84 |   106/  269 batches | lr 0.000916 | 255.91 ms | loss 0.01017 | ppl     1.01
# | epoch  84 |   159/  269 batches | lr 0.000916 | 254.05 ms | loss 0.01109 | ppl     1.01
# | epoch  84 |   212/  269 batches | lr 0.000916 | 317.03 ms | loss 0.01345 | ppl     1.01
# | epoch  84 |   265/  269 batches | lr 0.000916 | 269.21 ms | loss 0.01134 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time: 82.75s | valid loss 0.01428 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  85 |    53/  269 batches | lr 0.000898 | 259.51 ms | loss 0.01174 | ppl     1.01
# | epoch  85 |   106/  269 batches | lr 0.000898 | 254.38 ms | loss 0.01000 | ppl     1.01
# | epoch  85 |   159/  269 batches | lr 0.000898 | 260.70 ms | loss 0.01056 | ppl     1.01
# | epoch  85 |   212/  269 batches | lr 0.000898 | 263.24 ms | loss 0.01211 | ppl     1.01
# | epoch  85 |   265/  269 batches | lr 0.000898 | 258.66 ms | loss 0.01013 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time: 76.81s | valid loss 0.01508 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  86 |    53/  269 batches | lr 0.000880 | 259.52 ms | loss 0.01238 | ppl     1.01
# | epoch  86 |   106/  269 batches | lr 0.000880 | 255.82 ms | loss 0.00940 | ppl     1.01
# | epoch  86 |   159/  269 batches | lr 0.000880 | 263.55 ms | loss 0.01078 | ppl     1.01
# | epoch  86 |   212/  269 batches | lr 0.000880 | 262.91 ms | loss 0.01228 | ppl     1.01
# | epoch  86 |   265/  269 batches | lr 0.000880 | 255.38 ms | loss 0.01003 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time: 76.62s | valid loss 0.01779 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  87 |    53/  269 batches | lr 0.000862 | 258.20 ms | loss 0.01246 | ppl     1.01
# | epoch  87 |   106/  269 batches | lr 0.000862 | 258.20 ms | loss 0.00999 | ppl     1.01
# | epoch  87 |   159/  269 batches | lr 0.000862 | 261.03 ms | loss 0.01106 | ppl     1.01
# | epoch  87 |   212/  269 batches | lr 0.000862 | 262.41 ms | loss 0.01303 | ppl     1.01
# | epoch  87 |   265/  269 batches | lr 0.000862 | 253.98 ms | loss 0.01077 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time: 76.37s | valid loss 0.01692 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  88 |    53/  269 batches | lr 0.000845 | 260.51 ms | loss 0.01186 | ppl     1.01
# | epoch  88 |   106/  269 batches | lr 0.000845 | 259.60 ms | loss 0.01008 | ppl     1.01
# | epoch  88 |   159/  269 batches | lr 0.000845 | 265.26 ms | loss 0.01144 | ppl     1.01
# | epoch  88 |   212/  269 batches | lr 0.000845 | 258.69 ms | loss 0.01300 | ppl     1.01
# | epoch  88 |   265/  269 batches | lr 0.000845 | 254.73 ms | loss 0.01000 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time: 76.60s | valid loss 0.01507 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  89 |    53/  269 batches | lr 0.000828 | 259.25 ms | loss 0.01218 | ppl     1.01
# | epoch  89 |   106/  269 batches | lr 0.000828 | 261.57 ms | loss 0.00951 | ppl     1.01
# | epoch  89 |   159/  269 batches | lr 0.000828 | 262.34 ms | loss 0.01077 | ppl     1.01
# | epoch  89 |   212/  269 batches | lr 0.000828 | 257.68 ms | loss 0.01321 | ppl     1.01
# | epoch  89 |   265/  269 batches | lr 0.000828 | 254.47 ms | loss 0.01133 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time: 76.45s | valid loss 0.01260 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  90 |    53/  269 batches | lr 0.000812 | 259.83 ms | loss 0.01067 | ppl     1.01
# | epoch  90 |   106/  269 batches | lr 0.000812 | 261.22 ms | loss 0.00975 | ppl     1.01
# | epoch  90 |   159/  269 batches | lr 0.000812 | 262.56 ms | loss 0.01067 | ppl     1.01
# | epoch  90 |   212/  269 batches | lr 0.000812 | 256.11 ms | loss 0.01236 | ppl     1.01
# | epoch  90 |   265/  269 batches | lr 0.000812 | 253.44 ms | loss 0.01093 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time: 79.93s | valid loss 0.01204 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  91 |    53/  269 batches | lr 0.000795 | 259.19 ms | loss 0.01101 | ppl     1.01
# | epoch  91 |   106/  269 batches | lr 0.000795 | 254.19 ms | loss 0.00923 | ppl     1.01
# | epoch  91 |   159/  269 batches | lr 0.000795 | 254.35 ms | loss 0.01055 | ppl     1.01
# | epoch  91 |   212/  269 batches | lr 0.000795 | 255.11 ms | loss 0.01211 | ppl     1.01
# | epoch  91 |   265/  269 batches | lr 0.000795 | 254.90 ms | loss 0.01059 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time: 76.67s | valid loss 0.01155 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  92 |    53/  269 batches | lr 0.000779 | 258.59 ms | loss 0.01072 | ppl     1.01
# | epoch  92 |   106/  269 batches | lr 0.000779 | 254.90 ms | loss 0.00855 | ppl     1.01
# | epoch  92 |   159/  269 batches | lr 0.000779 | 309.23 ms | loss 0.00977 | ppl     1.01
# | epoch  92 |   212/  269 batches | lr 0.000779 | 276.01 ms | loss 0.01142 | ppl     1.01
# | epoch  92 |   265/  269 batches | lr 0.000779 | 254.90 ms | loss 0.00997 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time: 82.71s | valid loss 0.01158 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  93 |    53/  269 batches | lr 0.000764 | 259.38 ms | loss 0.01060 | ppl     1.01
# | epoch  93 |   106/  269 batches | lr 0.000764 | 254.27 ms | loss 0.00849 | ppl     1.01
# | epoch  93 |   159/  269 batches | lr 0.000764 | 254.16 ms | loss 0.01019 | ppl     1.01
# | epoch  93 |   212/  269 batches | lr 0.000764 | 253.68 ms | loss 0.01086 | ppl     1.01
# | epoch  93 |   265/  269 batches | lr 0.000764 | 253.82 ms | loss 0.00928 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time: 76.21s | valid loss 0.01191 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  94 |    53/  269 batches | lr 0.000749 | 257.26 ms | loss 0.01093 | ppl     1.01
# | epoch  94 |   106/  269 batches | lr 0.000749 | 255.70 ms | loss 0.00891 | ppl     1.01
# | epoch  94 |   159/  269 batches | lr 0.000749 | 253.08 ms | loss 0.01032 | ppl     1.01
# | epoch  94 |   212/  269 batches | lr 0.000749 | 253.27 ms | loss 0.01056 | ppl     1.01
# | epoch  94 |   265/  269 batches | lr 0.000749 | 253.60 ms | loss 0.00893 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time: 76.17s | valid loss 0.01240 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  95 |    53/  269 batches | lr 0.000734 | 259.22 ms | loss 0.01094 | ppl     1.01
# | epoch  95 |   106/  269 batches | lr 0.000734 | 253.34 ms | loss 0.00845 | ppl     1.01
# | epoch  95 |   159/  269 batches | lr 0.000734 | 252.75 ms | loss 0.00982 | ppl     1.01
# | epoch  95 |   212/  269 batches | lr 0.000734 | 254.07 ms | loss 0.01109 | ppl     1.01
# | epoch  95 |   265/  269 batches | lr 0.000734 | 255.31 ms | loss 0.00963 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time: 76.19s | valid loss 0.01234 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  96 |    53/  269 batches | lr 0.000719 | 258.14 ms | loss 0.01056 | ppl     1.01
# | epoch  96 |   106/  269 batches | lr 0.000719 | 254.41 ms | loss 0.00855 | ppl     1.01
# | epoch  96 |   159/  269 batches | lr 0.000719 | 253.88 ms | loss 0.01002 | ppl     1.01
# | epoch  96 |   212/  269 batches | lr 0.000719 | 253.78 ms | loss 0.01043 | ppl     1.01
# | epoch  96 |   265/  269 batches | lr 0.000719 | 253.26 ms | loss 0.00945 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  96 | time: 76.15s | valid loss 0.01117 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  97 |    53/  269 batches | lr 0.000705 | 257.63 ms | loss 0.01012 | ppl     1.01
# | epoch  97 |   106/  269 batches | lr 0.000705 | 254.06 ms | loss 0.00891 | ppl     1.01
# | epoch  97 |   159/  269 batches | lr 0.000705 | 254.88 ms | loss 0.01016 | ppl     1.01
# | epoch  97 |   212/  269 batches | lr 0.000705 | 253.47 ms | loss 0.01065 | ppl     1.01
# | epoch  97 |   265/  269 batches | lr 0.000705 | 254.35 ms | loss 0.00936 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  97 | time: 76.26s | valid loss 0.01236 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  98 |    53/  269 batches | lr 0.000690 | 257.77 ms | loss 0.01040 | ppl     1.01
# | epoch  98 |   106/  269 batches | lr 0.000690 | 253.88 ms | loss 0.00879 | ppl     1.01
# | epoch  98 |   159/  269 batches | lr 0.000690 | 252.64 ms | loss 0.01010 | ppl     1.01
# | epoch  98 |   212/  269 batches | lr 0.000690 | 253.78 ms | loss 0.01054 | ppl     1.01
# | epoch  98 |   265/  269 batches | lr 0.000690 | 252.85 ms | loss 0.00957 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  98 | time: 76.13s | valid loss 0.01289 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  99 |    53/  269 batches | lr 0.000677 | 258.11 ms | loss 0.01017 | ppl     1.01
# | epoch  99 |   106/  269 batches | lr 0.000677 | 253.20 ms | loss 0.00837 | ppl     1.01
# | epoch  99 |   159/  269 batches | lr 0.000677 | 252.88 ms | loss 0.00977 | ppl     1.01
# | epoch  99 |   212/  269 batches | lr 0.000677 | 254.06 ms | loss 0.01075 | ppl     1.01
# | epoch  99 |   265/  269 batches | lr 0.000677 | 255.39 ms | loss 0.00904 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time: 76.20s | valid loss 0.01160 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch 100 |    53/  269 batches | lr 0.000663 | 258.23 ms | loss 0.00908 | ppl     1.01
# | epoch 100 |   106/  269 batches | lr 0.000663 | 253.79 ms | loss 0.00851 | ppl     1.01
# | epoch 100 |   159/  269 batches | lr 0.000663 | 330.56 ms | loss 0.00939 | ppl     1.01
# | epoch 100 |   212/  269 batches | lr 0.000663 | 253.24 ms | loss 0.01034 | ppl     1.01
# | epoch 100 |   265/  269 batches | lr 0.000663 | 255.18 ms | loss 0.00956 | ppl     1.01
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time: 82.85s | valid loss 0.01087 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
